# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
% matplotlib inline

# %%
# 清洗数据表
df = pd.read_csv('CDNOW_master.txt', sep='\s+', header=None)
df.columns = ['id','date','quantity','amount']
df['date'] = pd.to_datetime(df['date'].astype(str))

# %%
df.head(10)
# Out:
#    id       date  quantity  amount
# 0   1 1997-01-01         1   11.77
# 1   2 1997-01-12         1   12.00
# 2   2 1997-01-12         5   77.00
# 3   3 1997-01-02         2   20.76
# 4   3 1997-03-30         2   20.76
# 5   3 1997-04-02         2   19.54
# 6   3 1997-11-15         5   57.45
# 7   3 1997-11-25         4   20.96
# 8   3 1998-05-28         1   16.99
# 9   4 1997-01-01         2   29.33

# %%
# 消费金额
ms = df.groupby('id')['amount'].sum()
ms.name = 'ms_amount'
ms.head()
# Out:
# id
# 1     11.77
# 2     89.00
# 3    156.46
# 4    100.50
# 5    385.61
# Name: ms_amount, dtype: float64

# %%
# 消费次数
fs = df.groupby('id')['amount'].count()
fs.name = 'fs_times'
fs.head()
# Out:
# id
# 1     1
# 2     2
# 3     6
# 4     4
# 5    11
# Name: fs_times, dtype: int64

# %%
# 最后一次消费时间距截止时间的时间间隔
rs = df['date'].max() - df.groupby('id')['date'].max() 
rs = rs.dt.days
rs.name = 'rs_delta'
rs.head()
# Out:
# id
# 1    545
# 2    534
# 3     33
# 4    200
# 5    178
# Name: rs_delta, dtype: int64

# %%
# 合并ms,fs,rs
df = pd.concat([ms,fs,rs], axis=1)
df.head()
# Out:
#     ms_amount  fs_times  rs_delta
# id
# 1       11.77         1       545
# 2       89.00         2       534
# 3      156.46         6        33
# 4      100.50         4       200
# 5      385.61        11       178

# %%
# 数据预处理：数据标准化
from sklearn import preprocessing
StandardScaler = preprocessing.StandardScaler().fit(df)
date = StandardScaler.transform(df)
data[0:5,:]
# Out:
# array([[-0.39145938, -0.41284215,  0.98107709],
#        [-0.07089664, -0.20171391,  0.92037314],
#        [ 0.20911322,  0.64279906, -1.84441563],
#        [-0.02316297,  0.22054257, -0.92281937],
#        [ 1.1602585 ,  1.69844027, -1.04422727]])

# %%
# 构建聚类模型
from sklearn.cluster import KMeans
kmeans_model = KMeans(n_clusters = 3,n_jobs=4)
fit_kmeans = kmeans_model.fit(data)

# %%
# 贴聚类标签
s = pd.Series(fit_kmeans.labels_, index=df.index)
s.name = 'label'
df1 = df.join(s)
df1.head()
# Out:
#     ms_amount  fs_times  rs_delta  label
# id
# 1       11.77         1       545      0
# 2       89.00         2       534      0
# 3      156.46         6        33      2
# 4      100.50         4       200      2
# 5      385.61        11       178      2

# %%
# 对聚类标签计数
s1 = df1['label'].value_counts()
s1.name = 'count'
s1
# Out:
# 0    16237
# 2     7183
# 1      150
# Name: count, dtype: int64

# %%
# 整合为聚类中心表
df2 = pd.DataFrame(fit_kmeans.cluster_centers_, index=s1.index, columns=df.columns).join(s1)
df2
# Out:
#    ms_amount  fs_times  rs_delta  count
# 0  -0.260981 -0.328882  0.623080  16237
# 2   7.807827  7.056875 -1.774146   7183
# 1   0.426893  0.596065 -1.371408    150

# %%
# 对聚类中心表排名
df2.rank(ascending=False)
# Out:
#    ms_amount  fs_times  rs_delta  count
# 0        3.0       3.0       1.0    1.0
# 2        1.0       1.0       3.0    2.0
# 1        2.0       2.0       2.0    3.0

# %%
# 雷达图展示聚类结果
from pyecharts import Radar

# 配置雷达图标签、值及其他
v1 = [list(df2.iloc[0,:3])]
v2 = [list(df2.iloc[1,:3])]
v3 = [list(df2.iloc[2,:3])]
c_schema= [{"name": "M", "max": 12, "min": -1},
           {"name": "F", "max": 10, "min": -1},
           {"name": "R", "max": 1, "min": -2},]

radar = Radar()
radar.config(c_schema=c_schema, shape='circle')
radar.add('客户群1', v1, item_color="#ff0000", symbol=None)
radar.add('客户群2', v2, item_color="#477725", symbol=None)
radar.add('客户群3', v3, item_color="#66ff00", symbol=None)

# 显示雷达图
radar
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="44d07418eaaf4c13aa5be3b3a1b12d26" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_44d07418eaaf4c13aa5be3b3a1b12d26 = echarts.init(document.getElementById('44d07418eaaf4c13aa5be3b3a1b12d26'), 'light', {renderer: 'canvas'});
#
# var option_44d07418eaaf4c13aa5be3b3a1b12d26 = {
#     "title": [
#         {
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "series_id": 3013190,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "radar",
#             "name": "\u5ba2\u6237\u7fa41",
#             "data": [
#                 [
#                     -0.2609806910071491,
#                     -0.32888236658718056,
#                     0.6230795750003282
#                 ]
#             ],
#             "symbol": "none",
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "itemStyle": {
#                 "normal": {
#                     "color": "#ff0000"
#                 }
#             },
#             "lineStyle": {
#                 "normal": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "areaStyle": {
#                 "opacity": 0
#             }
#         },
#         {
#             "type": "radar",
#             "name": "\u5ba2\u6237\u7fa42",
#             "data": [
#                 [
#                     7.807826892402563,
#                     7.05687505833573,
#                     -1.7741462178268639
#                 ]
#             ],
#             "symbol": "none",
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "itemStyle": {
#                 "normal": {
#                     "color": "#477725"
#                 }
#             },
#             "lineStyle": {
#                 "normal": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "areaStyle": {
#                 "opacity": 0
#             }
#         },
#         {
#             "type": "radar",
#             "name": "\u5ba2\u6237\u7fa43",
#             "data": [
#                 [
#                     0.426892586109237,
#                     0.5960645590320216,
#                     -1.3714076467500849
#                 ]
#             ],
#             "symbol": "none",
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "itemStyle": {
#                 "normal": {
#                     "color": "#66ff00"
#                 }
#             },
#             "lineStyle": {
#                 "normal": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "areaStyle": {
#                 "opacity": 0
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5ba2\u6237\u7fa41",
#                 "\u5ba2\u6237\u7fa42",
#                 "\u5ba2\u6237\u7fa43"
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "animation": true,
#     "radar": {
#         "indicator": [
#             {
#                 "name": "M",
#                 "max": 12,
#                 "min": -1
#             },
#             {
#                 "name": "F",
#                 "max": 10,
#                 "min": -1
#             },
#             {
#                 "name": "R",
#                 "max": 1,
#                 "min": -2
#             }
#         ],
#         "shape": "circle",
#         "name": {
#             "textStyle": {
#                 "color": "#333",
#                 "fontSize": 12
#             }
#         },
#         "splitLine": {
#             "show": true,
#             "lineStyle": {
#                 "normal": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         },
#         "splitArea": {
#             "show": true,
#             "areaStyle": {
#                 "opacity": 1
#             }
#         },
#         "axisLine": {
#             "show": true,
#             "lineStyle": {
#                 "normal": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     },
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ]
# };
# myChart_44d07418eaaf4c13aa5be3b3a1b12d26.setOption(option_44d07418eaaf4c13aa5be3b3a1b12d26);
#
#     });
# </script>
